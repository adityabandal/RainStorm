# %%
import pandas as pd

# Read the CSV file from the parent folder
df = pd.read_csv('../Traffic_Signs.csv')

# Display the first few rows of the dataframe
df.head()
# Out:
#               X             Y  OBJECTID              Sign_Type      Size_  \
# 0 -9.822752e+06  4.887654e+06         1  Streetname - Mast Arm  16" X 42"
# 1 -9.822752e+06  4.887683e+06         2  Streetname - Mast Arm  16" X 42"
# 2 -9.828662e+06  4.879484e+06         3              No Outlet  30" X 30"
# 3 -9.828960e+06  4.879770e+06         4              No Outlet  30" X 30"
# 4 -9.827840e+06  4.880135e+06         5              No Outlet  30" X 30"
#
#   Supplement                Sign_Post Year_Insta    Category Notes  MUTCD  \
# 0             Traffic Signal Mast Arm             Streetname         D3-1
# 1             Traffic Signal Mast Arm             Streetname         D3-1
# 2                    Punched Telespar       2010     Warning        W14-2
# 3                    Punched Telespar       2010     Warning        W14-2
# 4                    Punched Telespar       2010     Warning        W14-2
#
#    Ownership FACILITYID Schools Location_Adjusted Replacement_Zone  \
# ...
